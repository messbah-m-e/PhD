# %%
import numpy as np
from matplotlib import pyplot as plt, patches
import math
import random

# %%
data = np.array([
    [5, -2,10], 
    [0, 3,90], 
    [3, 8,58] 
]) 
# x, y = data.T

# %%
plt.scatter(x, y) 
plt.grid(True, which='both')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
circle1 = patches.Circle((5, -2), radius=math.sqrt(10), color='blue', linewidth=1,fill = False)
circle2 = patches.Circle((0, 3), radius=math.sqrt(90), color='green', linewidth=1,fill = False)
circle3 = patches.Circle((3, 8), radius=math.sqrt(58), color='red', linewidth=1,fill = False)
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)
ax.axis('equal')
plt.show()

# %%
[  0  -8  10]
 [-10   2  20]
 [ -4  12 -58]

# %%
# generate random number
rand = np.random.randint(10,size= 2)
print(data[0],rand)
# Out:
# [ 5 -2 10] [3 6]

# %%
abss = data[0,2] + (data[0][0]-rand[0])**2 + (data[0][1]-rand[1])**2
number = 2 * (data[0][0]-rand[0]) *(-data[0][0]) + 2 * (data[0][1]-rand[1]) *(-data[0][1])  + abss
w_x1 = 2 * (data[0][0]-rand[0])
w_x2 = 2 * (data[0][1]-rand[1])
(w_x1,w_x2,number)
# Out:
# (4, -16, 26)

# %%
matrix = []
for i in range(3):
    
    abss = data[0,2] + (data[ه][0]-rand[0])**2 + (data[0][1]-rand[1])**2
    number = 2 * (data[i][0]-rand[0]) *(-data[i][0]) + 2 * (data[i][1]-rand[1]) *(-data[i][1])  + abss

    w_x1 = 2 * (data[i][0]-rand[0])
    w_x2 = 2 * (data[i][1]-rand[1])
    matrix.append((w_x1,w_x2,number))
    print(w_x1,w_x2,number)
matrix = np.asarray(matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[223], line 4
#       1 matrix = []
#       2 for i in range(3):
# ----> 4     abss = data[0,2] + (data[0][0]-rand[0])**2 + (data[0][1]-rand[1])**2
#       6     number = 2 * (data[i][0]-rand[0]) *(-data[i][0]) + 2 * (data[i][1]-rand[1]) *(-data[i][1])  + abss
#       7     w_x1 = 2 * (data[i][0]-rand[0])
#
# ValueError: operands could not be broadcast together with shapes (2,) (0,)

# %%
a
# Out:
# [[14.5, -1.5], [4.5, 8.5]]

# %%
b
# Out:
# [-12.375, 37.625]

# %%
a= []
b= []
# x = random.randint(0,2)
for i in range(3):
    # if i !=x:
    a.append([matrix[i,0],matrix[i,1]])
    b.append([-matrix[i,2]])

# %%
np.asarray(a).shape
# Out:
# (3, 2)

# %%
np.asarray(b).shape
# Out:
# (3, 1)

# %%
np.linalg.lstsq(a, b)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8048\210800635.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   np.linalg.lstsq(a, b)
# (array([[1.34276375],
#         [3.67504509]]),
#  array([6788.95401262]),
#  2,
#  array([24.34950634, 12.82971321]))

# %%
rand = np.asarray([5,2])
# print("========================")
print("first point is :", rand)
# print("========================")
for j in range (3):
    matrix = []
    for i in range(3):

        abss = data[0,2] + (data[i][0]-rand[0])**2 + (data[i][1]-rand[1])**2
        number = 2 * (data[i][0]-rand[0]) *(-data[i][0]) + 2 * (data[i][1]-rand[1]) *(-data[i][1])  + abss
        w_x1 = 2 * (data[i][0]-rand[0])
        w_x2 = 2 * (data[i][1]-rand[1])
        matrix.append((w_x1,w_x2,number))

    matrix = np.asarray(matrix)
    print(matrix)

    a= []
    b= []
    for i in range(3):
        # if i !=x:
        a.append([matrix[i,0],matrix[i,1]])
        b.append([-matrix[i,2]])
    rand = np.linalg.lstsq(a, b,rcond=None)[0]
    rand= (rand[0][0],rand[1][0])
    print("========================")
    print(rand)
    print("========================")
# Out:
# first point is : [5 2]
# [[  0  -8  10]
#  [-10   2  30]
#  [ -4  12 -34]]
# ...
# (3.198717948717949, 3.0448717948717947)
# ...
# [[  3.6025641  -10.08974359   0.50304076]
#  [ -6.3974359   -0.08974359  20.50304076]
#  [ -0.3974359    9.91025641 -43.49695924]]
# ...
# (4.309900946633227, 3.0453465251912464)
# ...
# [[  1.38019811 -10.09069305   8.84938163]
#  [ -8.61980189  -0.09069305  28.84938163]
#  [ -2.61980189   9.90930695 -35.15061837]]
# ...
# (3.0552880160762053, 2.798207979125047)
# ...

# %%
[  0  -8  10]
[-10   2  20]
[ -4  12 -58]

# %%
rand = np.asarray([5,2])
rand
# Out:
# array([5, 2])

# %%
x = (rand[0][0],rand[1][0])

# %%
x
# Out:
# (3.198717948717949, 3.0448717948717947)

# %%
rand.shape
# Out:
# (2, 1)
